# %% [markdown]
# ## Tom Hanks' Filmography CSV
#
# In this notebook, we will:
#
# 1. Create a Spark session.
# 2. Read the Tom Hanks filmography CSV file.
# 3. Perform basic data inspection.

# %%
from pyspark.sql import SparkSession

# Create the Spark session
spark = SparkSession.builder \
    .appName("TomHanksFilmography") \
    .getOrCreate()
# Out:
# 24/12/09 22:17:32 WARN Utils: Your hostname, Marcellas-MacBook-Air.local resolves to a loopback address: 127.0.0.1; using 10.0.0.8 instead (on interface en0)
# 24/12/09 22:17:32 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/12/09 22:17:32 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/12/09 22:17:43 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
# read csv
df = spark.read.csv("/Users/marcellaferreira/pyspark/database/database.csv", header=True, inferSchema=True)

# %%
df.printSchema()
# Out:
# root
#  |-- movie_name: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- director: string (nullable = true)
#  |-- cost: string (nullable = true)
#  |-- box_office: string (nullable = true)
#  |-- role: string (nullable = true)

# %%
df.show(1000, truncate=False)
# Out:
# +-----------------------------------+----+---------------------+-----------------------+----------+----------------------------+
# |movie_name                         |year|director             |cost                   |box_office|role                        |
# +-----------------------------------+----+---------------------+-----------------------+----------+----------------------------+
# |He Knows You're Alone              |1980|Armand Mastroianni   |N/A                    |N/A       |Elliot                      |
# |Mazes and Monsters (TV)            |1982|Steven Hilliard Stern|N/A                    |N/A       |Robbie Wheeling             |
# |Splash                             |1984|Ron Howard           |N/A                    |N/A       |Allen Bauer                 |
# |Bachelor Party                     |1984|Neal Israel          |N/A                    |N/A       |Rick Gassko                 |
# ...
